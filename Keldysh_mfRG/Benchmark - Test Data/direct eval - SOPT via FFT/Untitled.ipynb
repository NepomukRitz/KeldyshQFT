# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi, imag
import h5py

# %%
f = h5py.File('SIAM_SOPT_FFT.h5', 'r')

# %%
keys = list(f.keys())

# %%
for i in range(0,len(keys)):
    print(f[keys[i]])
# Out:
# <HDF5 dataset "Gamma": shape (1,), type "<f8">
# <HDF5 dataset "ImPi_a_odd_even": shape (50000,), type "<f8">
# <HDF5 dataset "ImPi_a_odd_odd": shape (50000,), type "<f8">
# <HDF5 dataset "ImSE": shape (50000,), type "<f8">
# <HDF5 dataset "RePi_a_odd_even": shape (50000,), type "<f8">
# <HDF5 dataset "RePi_a_odd_odd": shape (50000,), type "<f8">
# <HDF5 dataset "ReSE": shape (50000,), type "<f8">
# <HDF5 dataset "U": shape (1,), type "<f8">
# <HDF5 dataset "v": shape (50000,), type "<f8">

# %%
Gamma = list(f[keys[0]])
print(Gamma)
# Out:
# [1.0]

# %%
ImPi_a_odd_even = list(f[keys[1]])
ImPi_a_odd_odd  = list(f[keys[2]])
ImSE = list(f[keys[3]])
RePi_a_odd_even = list(f[keys[4]])
RePi_a_odd_odd  = list(f[keys[5]])
ReSE = list(f[keys[6]])

# %%
U = list(f[keys[7]])
v = list(f[keys[8]])

# %%
data1 = np.loadtxt('Pia_odd_even.dat')
data2 = np.loadtxt('Pia_odd_odd.dat')

# %%
w = (data1[:,0])
RePi_a_odd_even_cxx = data1[:,1]
ImPi_a_odd_even_cxx = data1[:,2]

RePi_a_odd_odd_cxx = data2[:,1]
ImPi_a_odd_odd_cxx = data2[:,2]

# %%
plt.plot(v, np.multiply(ImPi_a_odd_even,2.))
plt.plot(w, ImPi_a_odd_even_cxx)
plt.plot(v, np.multiply(RePi_a_odd_even,2.))
plt.plot(w, RePi_a_odd_even_cxx)
plt.xlim(-20,20)
plt.grid()

# %%
plt.plot(v, ImPi_a_odd_odd)
plt.plot(v, RePi_a_odd_odd)
plt.xlim(-20,20)
plt.grid()

# %%
data3 = np.loadtxt('SelfEnergyR_cxx.dat')
data4 = np.loadtxt('SelfEnergyK_cxx.dat')

# %%
w2 = (data3[:,0])
ReSER = data3[:,1]
ImSER = data3[:,2]

ReSEK = data4[:,1]
ImSEK = data4[:,2]

# %%
plt.plot(v, ReSE)
plt.plot(v, ImSE)
plt.plot(w2, ReSER/3.5)
plt.plot(w2, ImSER/3.4)
plt.xlim(-20,20)
plt.grid()

# %%
Re_Pi_a_odd_even
